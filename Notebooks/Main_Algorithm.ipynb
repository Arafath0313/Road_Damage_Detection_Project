# %%
import cv2 
import os 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %run Extract_Function.ipynb
# %run Gray_Convert_Function.ipynb
# %run Denoise_Function.ipynb
# %run Contrast_Function.ipynb
# %run Canny_Function.ipynb
# %run Morphology_Function.ipynb
# %run Contour_Function.ipynb
# %run Final_Overlay_Function.ipynb
# %run Show_Combined_Frames.ipynb

# %%
video_path = r"C:\Users\arafa\Desktop\2403_Project_Work\Raw_Videos\Video.mov"
extract_function(video_path)
# Out:
#  Extracted 911 frames.
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Extract_Frames'

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Extract_Frames"

gray_convert_function(input_folder)
# Out:
# Grayscale conversion completed.
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Grayscale_Frames'

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Grayscale_Frames"

denoise_function(input_folder)
# Out:
# Noise reduction completed.
# Saved in: C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Denoised_Frames
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Denoised_Frames'

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Denoised_Frames"

contrast_function(input_folder)
# Out:
# Contrast enhancement completed.
# Saved in: C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Contrast_Frames
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Contrast_Frames'

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Contrast_Frames"

canny_function(input_folder)
# Out:
# Canny edge detection completed.
# Saved in: C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Canny_Frames
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Canny_Frames'

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Canny_Frames"

morph_folder = morphology_function(input_folder)
# Out:
# Morphology (light) completed.

# %%
input_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Morph_Frames"

contour_function(input_folder, min_area=300)
# Out:
#  Contour filtering + segmentation completed.
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Contour_Frames'

# %%
contour_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Contour_Frames"
gray_folder = r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Grayscale_Frames"

final_overlay_function(contour_folder, gray_folder, min_area=200)
# Out:
# ✅ Overlay detection (filtered borders) completed.
# 'C:\\Users\\arafa\\Desktop\\2403_Project_Work\\Dataset\\Segmented_Frames'

# %%
show_combined_frames(
    r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Extract_Frames",
    r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Contrast_Frames",
    r"C:\Users\arafa\Desktop\2403_Project_Work\Dataset\Segmented_Frames"
)
